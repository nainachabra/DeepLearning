# %% [markdown]
# BEGIN WITH DEEP LEARNING

# %%
#IMPORTING  LIBRARIES
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras.layers import Dense,Input
from tensorflow.keras.models import Sequential
from sklearn.model_selection import train_test_split

# %% [markdown]
# READING THE DATASET

# %%
df= pd.read_csv("bodyfat.csv")
df
# Out:
#      Density  BodyFat  Age  Weight  Height  Neck  Chest  Abdomen    Hip  \
# 0     1.0708     12.3   23  154.25   67.75  36.2   93.1     85.2   94.5
# 1     1.0853      6.1   22  173.25   72.25  38.5   93.6     83.0   98.7
# 2     1.0414     25.3   22  154.00   66.25  34.0   95.8     87.9   99.2
# 3     1.0751     10.4   26  184.75   72.25  37.4  101.8     86.4  101.2
# 4     1.0340     28.7   24  184.25   71.25  34.4   97.3    100.0  101.9
# ..       ...      ...  ...     ...     ...   ...    ...      ...    ...
# 247   1.0736     11.0   70  134.25   67.00  34.9   89.2     83.6   88.8
# 248   1.0236     33.6   72  201.00   69.75  40.9  108.5    105.0  104.5
# 249   1.0328     29.3   72  186.75   66.00  38.9  111.1    111.5  101.7
# 250   1.0399     26.0   72  190.75   70.50  38.9  108.3    101.3   97.8
# 251   1.0271     31.9   74  207.50   70.00  40.8  112.4    108.5  107.1
#
#      Thigh  Knee  Ankle  Biceps  Forearm  Wrist
# 0     59.0  37.3   21.9    32.0     27.4   17.1
# ...

# %%
df.shape
# Out:
# (252, 15)

# %% [markdown]
# NOTING DOWN THE NUMBER OF SAMPLES FEATURES AND OUTPUT CLASSES

# %%
num_samples = df.shape[0]
num_features = df.shape[1]
num_classes = 1

# %%
y = df['BodyFat']
X = df.drop('BodyFat',axis=1)       #REMOVING THE DEPENDENT VARIABLE

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2)       #SPLITTING THE DATASET INTO TRAINING AND TESTING

# %%
# KERAS SEQUENTIAL MODEL WITH 3 HIDDEN LAYERS OUT OF WHICH THE FIRST ONE HAS 128 NEURONS THE SECOND HAS 64 AND THE THIRD HAS 32 NEURONS WITH THE OUTPUT NEURON HAVING ONLY ONE OUTPUT NEURON

model = Sequential([
    Input(shape=(num_features-1,),name="s"),
    Dense(128,activation="relu",name="d1"),
    Dense(64,activation="relu",name="d2"),
    Dense(32,activation="relu",name="d3"),
    Dense(1,activation="linear")
])

# %%
model.summary()         #SUMMARIZING
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  d1 (Dense)                  (None, 128)               1920
#
#  d2 (Dense)                  (None, 64)                8256
#
#  d3 (Dense)                  (None, 32)                2080
#
#  dense (Dense)               (None, 1)                 33
#
# ...
# Total params: 12,289
# Trainable params: 12,289
# Non-trainable params: 0
# _________________________________________________________________

# %%
#COMPILING THE MODEL WITH ADAM ALGORITHM AND SINCE THIS IS A REGRESSION PROBLEM THIS METRICS USED IS ROOTMEANSQUAREDERROR AND LOSS IS MEAN SQUEARED LOSS

model.compile(optimizer="adam",loss="mean_squared_error",metrics=['RootMeanSquaredError'])

# %%
#FITING THE MODEL WITH TRAINING DATA BY TAKING THE BATCH SIZE AS 32 AND 100 EPOCHS ALONG WITH 0.1 VALIDATION SPLIT

model.fit(X_train,y_train,batch_size=32,epochs=100,validation_split=0.1)
# Out:
# Epoch 1/100
# 6/6 [==============================] - 1s 41ms/step - loss: 69.4246 - root_mean_squared_error: 8.3321 - val_loss: 69.3270 - val_root_mean_squared_error: 8.3263
# Epoch 2/100
# 6/6 [==============================] - 0s 12ms/step - loss: 40.8139 - root_mean_squared_error: 6.3886 - val_loss: 27.8169 - val_root_mean_squared_error: 5.2742
# Epoch 3/100
# 6/6 [==============================] - 0s 8ms/step - loss: 28.3003 - root_mean_squared_error: 5.3198 - val_loss: 49.0460 - val_root_mean_squared_error: 7.0033
# Epoch 4/100
# 6/6 [==============================] - 0s 12ms/step - loss: 21.8017 - root_mean_squared_error: 4.6692 - val_loss: 27.9794 - val_root_mean_squared_error: 5.2896
# Epoch 5/100
# 6/6 [==============================] - 0s 9ms/step - loss: 24.5121 - root_mean_squared_error: 4.9510 - val_loss: 35.1526 - val_root_mean_squared_error: 5.9290
# Epoch 6/100
# ...

# %%
# MODEL BASED ON THE TEST DATA AND BATCH SIZE AS 32

loss,accuracy = model.evaluate(X_test,y_test,batch_size=32)
print("Test Loss:", loss)
print("Test Accuracy:", accuracy)
# Out:
# 2/2 [==============================] - 0s 8ms/step - loss: 16.1277 - root_mean_squared_error: 4.0159
# Test Loss: 16.127723693847656
# Test Accuracy: 4.015933513641357
